# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
data_path = Path("C://Users//prana//Downloads//Annadata//data//raw//crop_yield//Indian//crop_yield.csv")
df = pd.read_csv(data_path)

# %%
print("Dataset shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Dataset shape: (5840, 20)
#
# Data Types:
#  timestamp                           object
# region_name                         object
# temperature_current                float64
# temperature_min                    float64
# temperature_max                    float64
# temperature_growing_degree_days    float64
# humidity_relative_humidity           int64
# humidity_pressure                  float64
# precipitation_rain_1h              float64
# precipitation_rain_3h              float64
# wind_speed                         float64
# wind_gust                          float64
# wind_degree                          int64
# cloud_cover                          int64
# weather_main                        object
# weather_description                 object
# extreme_weather_is_rainy              bool
# extreme_weather_is_thunderstorm       bool
# extreme_weather_is_clear              bool
# extreme_weather_is_cloudy             bool
# dtype: object
#
# Missing Values:
#  timestamp                          0
# region_name                        0
# temperature_current                0
# temperature_min                    0
# temperature_max                    0
# temperature_growing_degree_days    0
# humidity_relative_humidity         0
# humidity_pressure                  0
# precipitation_rain_1h              0
# precipitation_rain_3h              0
# wind_speed                         0
# wind_gust                          0
# wind_degree                        0
# cloud_cover                        0
# weather_main                       0
# weather_description                0
# extreme_weather_is_rainy           0
# extreme_weather_is_thunderstorm    0
# extreme_weather_is_clear           0
# extreme_weather_is_cloudy          0
# dtype: int64

# %%
print("\nStatistical Summary:\n", df.describe())
# Out:
# Statistical Summary:
#            Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# 75%    1.000385e+07  2.004170e+04      2.388889
# max    4.835407e+09  1.575051e+07  21105.000000
